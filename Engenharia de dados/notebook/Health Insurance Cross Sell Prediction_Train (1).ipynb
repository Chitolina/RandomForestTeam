# %% [markdown]
# ## Limpeza e Tranformação de dados

# %%
df_train = spark\
           .read.format('csv')\
           .option('InferSchema','true')\
           .option('header','true')\
           .csv('/FileStore/tables/landing/train.csv')

# %%
df_train.show(5)
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# |  1|  Male| 44|              1|       28.0|                 0|  > 2 Years|           Yes|       40454.0|                26.0|    217|       1|
# |  2|  Male| 76|              1|        3.0|                 0|   1-2 Year|            No|       33536.0|                26.0|    183|       0|
# |  3|  Male| 47|              1|       28.0|                 0|  > 2 Years|           Yes|       38294.0|                26.0|     27|       1|
# ...

# %%
df_train.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Driving_License: integer (nullable = true)
#  |-- Region_Code: double (nullable = true)
#  |-- Previously_Insured: integer (nullable = true)
#  |-- Vehicle_Age: string (nullable = true)
#  |-- Vehicle_Damage: string (nullable = true)
#  |-- Annual_Premium: double (nullable = true)
#  |-- Policy_Sales_Channel: double (nullable = true)
#  |-- Vintage: integer (nullable = true)
#  |-- Response: integer (nullable = true)

# %% [markdown]
# Quantidade de linhas

# %%
df_train.count()
# Out:
# Out[53]: 381109

# %% [markdown]
# Consultando  o ID para ver se temos eles duplos

# %%
df_train.select('id').distinct().count()
# Out:
# Out[54]: 381109

# %% [markdown]
# Consultando as colunas da tabela para ver se  tem valores null

# %%
df_train.filter('id is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Gender is NULL').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Driving_License is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Region_Code is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Previously_Insured is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Vehicle_Age is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Vehicle_Damage is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Annual_Premium is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Policy_Sales_Channel is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Vintage is null').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %%
df_train.filter('Response is NULL').show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+

# %% [markdown]
# Removendo todos os valores NA no Data Frame

# %%
df_train.na.drop().show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# |  1|  Male| 44|              1|       28.0|                 0|  > 2 Years|           Yes|       40454.0|                26.0|    217|       1|
# |  2|  Male| 76|              1|        3.0|                 0|   1-2 Year|            No|       33536.0|                26.0|    183|       0|
# |  3|  Male| 47|              1|       28.0|                 0|  > 2 Years|           Yes|       38294.0|                26.0|     27|       1|
# ...

# %% [markdown]
# Colunas categóricas Gender, Vehicle_Age e Vehicle_Damage alteradas para numéricas.

# %%
from pyspark.sql.functions import col , regexp_replace

# %%
df_train=df_train.withColumn('Vehicle_Age',regexp_replace(df_train['Vehicle_Age'],'> 2 Years','2'))

# %%
df_train=df_train.withColumn('Vehicle_Age',regexp_replace(df_train['Vehicle_Age'],'< 1 Year','0'))

# %%
df_train=df_train.withColumn('Vehicle_Age',regexp_replace(df_train['Vehicle_Age'],'1-2 Year','1'))

# %%
df_train.select('Vehicle_Age').show(6)
# Out:
# +-----------+
# |Vehicle_Age|
# +-----------+
# |          2|
# |          1|
# |          2|
# |          0|
# |          0|
# |          0|
# +-----------+
# only showing top 6 rows

# %%
df_train.show()
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# |  1|  Male| 44|              1|       28.0|                 0|          2|           Yes|       40454.0|                26.0|    217|       1|
# |  2|  Male| 76|              1|        3.0|                 0|          1|            No|       33536.0|                26.0|    183|       0|
# |  3|  Male| 47|              1|       28.0|                 0|          2|           Yes|       38294.0|                26.0|     27|       1|
# ...

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, DoubleType, TimestampType

# %%
# mudar s Schema da coluna Vehicle_Age de String para Integer
#Convert String to Integer Type

df_train = df_train.withColumn("Vehicle_Age",col("Vehicle_Age").cast(IntegerType()))

# %%
df_train.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Driving_License: integer (nullable = true)
#  |-- Region_Code: double (nullable = true)
#  |-- Previously_Insured: integer (nullable = true)
#  |-- Vehicle_Age: integer (nullable = true)
#  |-- Vehicle_Damage: string (nullable = true)
#  |-- Annual_Premium: double (nullable = true)
#  |-- Policy_Sales_Channel: double (nullable = true)
#  |-- Vintage: integer (nullable = true)
#  |-- Response: integer (nullable = true)

# %% [markdown]
# Coluna  Gender transformando 'Female': 0, 'Male': 1

# %%
from pyspark.sql.functions import col , regexp_replace

# %%
df_train=df_train.withColumn('Gender',regexp_replace(df_train['Gender'],'Female','0'))

# %%
df_train=df_train.withColumn('Gender',regexp_replace(df_train['Gender'],'Male','1'))

# %%
df_train.select('Gender').show(5)
# Out:
# +------+
# |Gender|
# +------+
# |     1|
# |     1|
# |     1|
# |     1|
# |     0|
# +------+
# only showing top 5 rows

# %%
df_train.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Driving_License: integer (nullable = true)
#  |-- Region_Code: double (nullable = true)
#  |-- Previously_Insured: integer (nullable = true)
#  |-- Vehicle_Age: integer (nullable = true)
#  |-- Vehicle_Damage: string (nullable = true)
#  |-- Annual_Premium: double (nullable = true)
#  |-- Policy_Sales_Channel: double (nullable = true)
#  |-- Vintage: integer (nullable = true)
#  |-- Response: integer (nullable = true)

# %% [markdown]
# Mudando a coluna Gender de String para  int

# %%
# 
df_train = df_train.withColumn("Gender",col("Gender").cast(IntegerType()))

# %%
df_train.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Gender: integer (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Driving_License: integer (nullable = true)
#  |-- Region_Code: double (nullable = true)
#  |-- Previously_Insured: integer (nullable = true)
#  |-- Vehicle_Age: integer (nullable = true)
#  |-- Vehicle_Damage: string (nullable = true)
#  |-- Annual_Premium: double (nullable = true)
#  |-- Policy_Sales_Channel: double (nullable = true)
#  |-- Vintage: integer (nullable = true)
#  |-- Response: integer (nullable = true)

# %% [markdown]
# Mudando a coluna Gender 'Vehicle_Damage' para 'No': 0, 'Yes': 1 e de String para  int

# %%
df_train=df_train.withColumn('Vehicle_Damage',regexp_replace(df_train['Vehicle_Damage'],'No','0'))

# %%
df_train=df_train.withColumn('Vehicle_Damage',regexp_replace(df_train['Vehicle_Damage'],'Yes','1'))

# %%
df_train.select('Vehicle_Damage').show(5)
# Out:
# +--------------+
# |Vehicle_Damage|
# +--------------+
# |             1|
# |             0|
# |             1|
# |             0|
# |             0|
# +--------------+
# only showing top 5 rows

# %%
# mudando a coluna Gender de String para  int
df_train = df_train.withColumn('Vehicle_Damage',col('Vehicle_Damage').cast(IntegerType()))

# %%
df_train.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Gender: integer (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Driving_License: integer (nullable = true)
#  |-- Region_Code: double (nullable = true)
#  |-- Previously_Insured: integer (nullable = true)
#  |-- Vehicle_Age: integer (nullable = true)
#  |-- Vehicle_Damage: integer (nullable = true)
#  |-- Annual_Premium: double (nullable = true)
#  |-- Policy_Sales_Channel: double (nullable = true)
#  |-- Vintage: integer (nullable = true)
#  |-- Response: integer (nullable = true)

# %%
df_train.show(6)
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# |  1|     1| 44|              1|       28.0|                 0|          2|             1|       40454.0|                26.0|    217|       1|
# |  2|     1| 76|              1|        3.0|                 0|          1|             0|       33536.0|                26.0|    183|       0|
# |  3|     1| 47|              1|       28.0|                 0|          2|             1|       38294.0|                26.0|     27|       1|
# ...

# %% [markdown]
# Mudando coluna 'Driving_License' 0: "No", 1: "Yes"

# %%
df_train=df_train.withColumn('Driving_License',regexp_replace(df_train['Driving_License'],'1','Yes'))

# %%
df_train=df_train.withColumn('Driving_License',regexp_replace(df_train['Driving_License'],'0','No'))

# %%
# mudando coluna 'Driving_License de Integer para String
df_train = df_train.withColumn('Driving_License',col('Driving_License').cast(StringType()))

# %%
df_train.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Gender: integer (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Driving_License: string (nullable = true)
#  |-- Region_Code: double (nullable = true)
#  |-- Previously_Insured: string (nullable = true)
#  |-- Vehicle_Age: integer (nullable = true)
#  |-- Vehicle_Damage: integer (nullable = true)
#  |-- Annual_Premium: double (nullable = true)
#  |-- Policy_Sales_Channel: double (nullable = true)
#  |-- Vintage: integer (nullable = true)
#  |-- Response: integer (nullable = true)

# %% [markdown]
# Mudando a coluna 'Driving_License'  de 0: "No", 1: "Yes"

# %%
df_train=df_train.withColumn('Previously_Insured',regexp_replace(df_train['Previously_Insured'],'1','Yes'))

# %%
df_train=df_train.withColumn('Previously_Insured',regexp_replace(df_train['Previously_Insured'],'0','No'))

# %%
# mudando coluna 'Driving_License de Integer para String
df_train = df_train.withColumn('Previously_Insured',col('Previously_Insured').cast(StringType()))

# %%
df_train.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Gender: integer (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Driving_License: string (nullable = true)
#  |-- Region_Code: double (nullable = true)
#  |-- Previously_Insured: string (nullable = true)
#  |-- Vehicle_Age: integer (nullable = true)
#  |-- Vehicle_Damage: integer (nullable = true)
#  |-- Annual_Premium: double (nullable = true)
#  |-- Policy_Sales_Channel: double (nullable = true)
#  |-- Vintage: integer (nullable = true)
#  |-- Response: integer (nullable = true)

# %%
df_train.show(50)
# Out:
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# | id|Gender|Age|Driving_License|Region_Code|Previously_Insured|Vehicle_Age|Vehicle_Damage|Annual_Premium|Policy_Sales_Channel|Vintage|Response|
# +---+------+---+---------------+-----------+------------------+-----------+--------------+--------------+--------------------+-------+--------+
# |  1|     1| 44|            Yes|       28.0|                No|          2|             1|       40454.0|                26.0|    217|       1|
# |  2|     1| 76|            Yes|        3.0|                No|          1|             0|       33536.0|                26.0|    183|       0|
# |  3|     1| 47|            Yes|       28.0|                No|          2|             1|       38294.0|                26.0|     27|       1|
# ...

# %% [markdown]
# Transfomando as Tabela para o formato parquet e subindo as Datas no Data Lake

# %%
df_train.write.format('parquet')\
    .mode('overwrite')\
   .save('/FileStore/tables/processing/train.parquet')

# %%
# %fs
ls /FileStore/tables/processing/train.parquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
